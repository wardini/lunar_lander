# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Moon 2
N=40
dx1=30*np.random.random(N)
dx2=30*np.random.random(N)
x=np.zeros(2*dx1.shape[0]+2)
x[N]=-25
x[N+1]=25
for i in range(N):
    x[N-1-i]=x[N-i]-dx1[i]
    x[N+2+i]=x[N+1+i]+dx2[i]
y=40*np.random.random(x.shape[0])-10
y[N]=-0.01
y[N+1]=-0.01

# %%
plt.figure()
plt.plot(x,y)
plt.gca().set_aspect(1.0) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.append(x,[10000,10000,-10000,-10000])
y = np.append(y,[   0,-10000,-10000,0])
print(list(zip(x,y)))
# Out:
# [(-623.5153589634232, 22.625363016480165), (-603.8751746563224, 20.1521478644425), (-591.8458862315613, -3.3364578817568313), (-577.6717403597725, 27.494067519035355), (-553.1819289047901, 20.56064533105719), (-544.9040711941132, 12.74335327245231), (-537.1906781473908, 24.263416866992202), (-520.1353465166364, 21.327308615748212), (-493.7680019981379, 26.167856918635202), (-473.93268454595227, -3.2264621363937662), (-468.800831879207, 20.641727769990897), (-460.0462113654709, -6.754556997227339), (-438.52560705617856, 2.8417746726121162), (-415.18922399464276, 7.6368048970097036), (-393.84759472095993, 18.921216762515314), (-373.9788737560246, 14.908386727370555), (-345.35870060324, 13.219715030679616), (-327.9353432907176, 23.205231613457684), (-311.50483499817125, -3.712808257829634), (-296.8207118050664, 23.42242472382631), (-273.8624828893499, 26.286590836668154), (-247.58978158560691, 18.54337513367511), (-234.3791653842953, 17.340045596959), (-229.13795710133954, -6.2785073820
# ...

# %%
# Moon 2
N=40
dx1=30*np.random.random(N)
dx2=30*np.random.random(N)
x=np.zeros(2*dx1.shape[0]+2)
x[N]=25
x[N+1]=75
for i in range(N):
    x[N-1-i]=x[N-i]-dx1[i]
    x[N+2+i]=x[N+1+i]+dx2[i]
y=N*np.random.random(x.shape[0])-10
y[N]=-0.01
y[N+1]=-0.01

# %%
plt.figure()
plt.plot(x,y)
plt.gca().set_aspect(1.0) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.append(x,[10000,10000,-10000,-10000])
y = np.append(y,[   0,-10000,-10000,0])
print(list(zip(x,y)))
# Out:
# [(-483.972809575778, 25.000622814990706), (-470.5511551803862, 28.024165567088673), (-452.78242641036593, 5.049122869783531), (-442.4467716383329, 6.749291426096743), (-436.2554073578322, 27.833885406565685), (-428.3996659615821, 28.5666986625223), (-419.8669431681572, 20.190416692106027), (-411.61700025468673, -5.048160118538507), (-392.7116655691976, 9.705810724699436), (-391.51742714436074, 27.664258343045006), (-391.37806639984296, 17.382457674878957), (-375.9823299184898, 29.434914904807307), (-372.3838764416577, 0.5381713248474327), (-344.7926944175608, -1.1622529345052826), (-316.2287891251925, 12.185500029284533), (-302.94034871834646, -9.027308841633147), (-284.8440003321587, 10.809839637062222), (-283.1397149832893, -8.212361239913196), (-273.6120811546043, 15.313320907753166), (-259.3571145621429, 5.008329122761221), (-241.16905054443328, -4.130130813693742), (-240.78801770046874, 10.584658233649833), (-239.18153156015916, -3.5201329354053312), (-235.08471413657108, -6.297
# ...

# %%
# Asteroid
N=100
R=1000
dR=140
Lz=np.array([[1000,-25],[1000,25]])
adelta=np.random.random(N)
rdelta=dR*np.random.random(N)-dR/2
adelta= adelta*(2*np.pi-np.arctan(50/1000)-np.arctan(10/1000))/np.sum(adelta)
last_angle=np.arctan(25/1000)
x = np.zeros(N+2)
y = np.zeros(N+2)
x[0]=Lz[0,0]
x[1]=Lz[1,0]
y[0]=Lz[0,1]
y[1]=Lz[1,1]
for i in range(N):
    last_angle += adelta[i]
    x[i+2]=(R+rdelta[i])*np.cos(last_angle)
    y[i+2]=(R+rdelta[i])*np.sin(last_angle)
print(list(zip(x,y)))
# Out:
# [(1000.0, -25.0), (1000.0, 25.0), (940.752064552036, 66.22677233182682), (1011.967008588309, 137.05982032438206), (993.0272071731315, 256.5615610107261), (979.2981250856371, 328.52653719030354), (938.6947087568644, 428.14050831154015), (942.5420566820884, 460.6520221265791), (809.0237672333355, 481.40036945752485), (822.4839154531171, 553.8763759325348), (784.1230234514951, 614.2953222267261), (702.966909616134, 695.6945063351105), (645.8253521898364, 784.040099060557), (637.993446933123, 829.4268577343568), (573.8200855760355, 876.122438230395), (519.5685957161564, 838.133487199627), (534.7950914931669, 869.7468339226602), (438.89313134167446, 893.1978422525424), (411.2989032970871, 891.0324522966104), (365.7790989906949, 970.7433528424145), (346.65817704385563, 928.9711341956297), (264.836525747947, 1008.7137539538451), (268.60998146823607, 1027.4774545407306), (141.54325142530615, 1045.21679103604), (63.32622348630093, 1029.8013057074506), (-45.87385157317194, 933.0900357229972), 
# ...

# %%
plt.figure()
plt.plot(x,y)
plt.gca().set_aspect(1.0) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Double Asteroid
# Asteroid #1 which has the landing zone
N=100
R=1000
dR=140
Lz=np.array([[1000,-25],[1000,25]])
adelta=np.random.random(N)
rdelta=dR*np.random.random(N)-dR/2
adelta= adelta*(2*np.pi-np.arctan(50/1000)-np.arctan(10/1000))/np.sum(adelta)
last_angle=np.arctan(25/1000)
x = np.zeros(N+2)
y = np.zeros(N+2)
x[0]=Lz[0,0]
x[1]=Lz[1,0]
y[0]=Lz[0,1]
y[1]=Lz[1,1]
for i in range(N):
    last_angle += adelta[i]
    x[i+2]=(R+rdelta[i])*np.cos(last_angle)
    y[i+2]=(R+rdelta[i])*np.sin(last_angle)
x=x-2000

# Asteroid #2
N=100
R=1000
dR=140
adelta=np.random.random(N)
rdelta=dR*np.random.random(N)-dR/2
adelta= adelta*2*np.pi/np.sum(adelta)
last_angle=np.arctan(25/1000)
x2 = np.zeros(N)
y2 = np.zeros(N)
for i in range(N):
    last_angle += adelta[i]
    x2[i]=(R+rdelta[i])*np.cos(last_angle)
    y2[i]=(R+rdelta[i])*np.sin(last_angle)
x2=x2+2000

print('[')    
print(list(zip(x,y)))
print(',')
print(list(zip(x2,y2)))
print(']')
# Out:
# [
# ...

# %%
# Now try a much smaller binary asteroid
# Double Asteroid
# Asteroid #1 which has the landing zone
N=50
R=400
dR=140
Lz=np.array([[400,-25],[400,25]])
adelta=np.random.random(N)
rdelta=dR*np.random.random(N)-dR/2
adelta= adelta*(2*np.pi-np.arctan(50/R)-np.arctan(10/R))/np.sum(adelta)
last_angle=np.arctan(25/1000)
x = np.zeros(N+2)
y = np.zeros(N+2)
x[0]=Lz[0,0]
x[1]=Lz[1,0]
y[0]=Lz[0,1]
y[1]=Lz[1,1]
for i in range(N):
    last_angle += adelta[i]
    x[i+2]=(R+rdelta[i])*np.cos(last_angle)
    y[i+2]=(R+rdelta[i])*np.sin(last_angle)
x=x-600

# Asteroid #2
N=50
R=400
dR=140
adelta=np.random.random(N)
rdelta=dR*np.random.random(N)-dR/2
adelta= adelta*2*np.pi/np.sum(adelta)
last_angle=np.arctan(25/1000)
x2 = np.zeros(N)
y2 = np.zeros(N)
for i in range(N):
    last_angle += adelta[i]
    x2[i]=(R+rdelta[i])*np.cos(last_angle)
    y2[i]=(R+rdelta[i])*np.sin(last_angle)
x2=x2+600

print('[')    
print(list(zip(x,y)))
print(',')
print(list(zip(x2,y2)))
print(']')
# Out:
# [
# ...

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x2,y2)
plt.gca().set_aspect(1.0) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Starship
x1=np.array([2,13,15,16,15,15,16,15,13,2])
y1=np.array([2,2,0,0,2,4,6,6,4,4])

x2=np.array([7,10,7,4])
y2=np.array([4,4,7,7])

x3=np.array([0,2,22,22,18,16,11,10,0])
y3=np.array([8,7,7,9,9,11,11,10,10])

x4=np.array([22,24,27,29,29,27,24,22])
y4=np.array([7,5,5,7,9,11,11,9])

x5=np.array([0,3,5,8,8,1,1,2,0])
y5=np.array([10,10,13,13,15,15,13,13,10])

lzx=np.array([11,16])
lzy=np.array([11,11])

M=6
x1*=M
y1*=M
x2*=M
y2*=M
x3*=M
y3*=M
x4*=M
y4*=M
x5*=M
y5*=M
lzx*=M
lzy*=M


plt.figure()
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.plot(x4,y4)
plt.plot(x5,y5)

plt.plot(lzx,lzy)

plt.gca().set_aspect(1.0) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('[',list(zip(x1,y1)),',',list(zip(x2,y2)),',',list(zip(x3,y3)),',',list(zip(x4,y4)),',',list(zip(x5,y5)) ,']')
# Out:
# [ [(12, 12), (78, 12), (90, 0), (96, 0), (90, 12), (90, 24), (96, 36), (90, 36), (78, 24), (12, 24)] , [(42, 24), (60, 24), (42, 42), (24, 42)] , [(0, 48), (12, 42), (132, 42), (132, 54), (108, 54), (96, 66), (66, 66), (60, 60), (0, 60)] , [(132, 42), (144, 30), (162, 30), (174, 42), (174, 54), (162, 66), (144, 66), (132, 54)] , [(0, 60), (18, 60), (30, 78), (48, 78), (48, 90), (6, 90), (6, 78), (12, 78), (0, 60)] ]

# %%
print(list(zip(lzx,lzy)))
# Out:
# [(66, 66), (96, 66)]
